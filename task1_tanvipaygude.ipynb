# %%
import pandas as pd

# %%
data=pd.read_csv("car_prices.csv")

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
print("Missing values before cleaning:\n", data.isnull().sum())
data=data.dropna()
# Out:
# Missing values before cleaning:
#  year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558831  2011     BMW             5 Series         528i      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# ...

# %%
# 2. Remove duplicate rows
data = data.drop_duplicates()
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558831  2011     BMW             5 Series         528i      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# ...

# %%
# 3. Standardize text values (example for text columns)
text_columns = ['make', 'model', 'trim', 'body', 'transmission', 'state', 'color', 'interior', 'seller']
for col in text_columns:
    if col in data.columns:
        data[col] = data[col].astype(str).str.lower().str.strip()

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     kia              sorento           lx        suv
# 1       2015     kia              sorento           lx        suv
# 2       2014     bmw             3 series   328i sulev      sedan
# 3       2015   volvo                  s60           t5      sedan
# 4       2014     bmw  6 series gran coupe         650i      sedan
# ...      ...     ...                  ...          ...        ...
# 558831  2011     bmw             5 series         528i      sedan
# 558833  2012     ram                 2500  power wagon   crew cab
# 558834  2012     bmw                   x5    xdrive35d        suv
# 558835  2015  nissan               altima        2.5 s      sedan
# 558836  2014    ford                f-150          xlt  supercrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# ...

# %%
# 4. Convert date formats to a consistent type (e.g., dd-mm-yyyy)
data['saledate'] = pd.to_datetime(data['saledate'], errors='coerce', utc=True)
data['saledate'] = data['saledate'].dt.tz_localize(None).dt.strftime('%d-%m-%Y')

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     kia              sorento           lx        suv
# 1       2015     kia              sorento           lx        suv
# 2       2014     bmw             3 series   328i sulev      sedan
# 3       2015   volvo                  s60           t5      sedan
# 4       2014     bmw  6 series gran coupe         650i      sedan
# ...      ...     ...                  ...          ...        ...
# 558831  2011     bmw             5 series         528i      sedan
# 558833  2012     ram                 2500  power wagon   crew cab
# 558834  2012     bmw                   x5    xdrive35d        suv
# 558835  2015  nissan               altima        2.5 s      sedan
# 558836  2014    ford                f-150          xlt  supercrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# ...

# %%
# 5. Rename column headers to be clean and uniform
data.columns = [col.lower().replace(" ", "_") for col in data.columns]
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     kia              sorento           lx        suv
# 1       2015     kia              sorento           lx        suv
# 2       2014     bmw             3 series   328i sulev      sedan
# 3       2015   volvo                  s60           t5      sedan
# 4       2014     bmw  6 series gran coupe         650i      sedan
# ...      ...     ...                  ...          ...        ...
# 558831  2011     bmw             5 series         528i      sedan
# 558833  2012     ram                 2500  power wagon   crew cab
# 558834  2012     bmw                   x5    xdrive35d        suv
# 558835  2015  nissan               altima        2.5 s      sedan
# 558836  2014    ford                f-150          xlt  supercrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# ...
